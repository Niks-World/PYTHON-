# %%
x= np.arange (0.10,1)
y= 2*x+5 
plt.stackplot(x,y,color='green',alpha=0.9)
plt.plot(x,y,color='m')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x= np.arange (1,5)
y= [1,4,6,8,4,5,3,2,1,5,6,8,7] 
plt.stackplot(x,y,color='Black',alpha=0.5)
plt.plot(x,y,color='g')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8bcc3beaebc9> in <module>
#       4 x= np.arange (1,5)
#       5 y= [1,4,6,8,4,5,3,2,1,5,6,8,7]
# ----> 6 plt.stackplot(x,y,color='Black',alpha=0.5)
#       7 plt.plot(x,y,color='g')
#       8 plt.grid(True)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in stackplot(x, labels, colors, baseline, data, *args, **kwargs)
#    2899     return gca().stackplot(
#    2900         x, *args, labels=labels, colors=colors, baseline=baseline,
# -> 2901         **({"data": data} if data is not None else {}), **kwargs)
#    2902
#    2903
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...

# %%
x= np.arange (10,1)
y= 2* + 5

plt.stackplot(x,y,color='green',alpha=0.9)

plt.plot(x,y,color='black')

plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-502c2aedd66e> in <module>
#       4 plt.stackplot(x,y,color='green',alpha=0.9)
#       5
# ----> 6 plt.plot(x,y,color='black')
#       7
#       8 plt.grid(True)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ...
